# %%
# !pip install -q streamlit ultralytics pyngrok

# 1. كتابة ملف الـ App
with open('app.py', 'w') as f:
    f.write('''
import streamlit as st
from ultralytics import YOLO
from PIL import Image

st.title("YOLOv8 Streamlit App 🚀")
model = YOLO("yolov8n.pt")

uploaded_file = st.file_uploader("Upload Image", type=["jpg", "png", "jpeg"])
if uploaded_file:
    image = Image.open(uploaded_file)
    st.image(image, caption="Original")
    if st.button("Detect"):
        results = model(image)
        st.image(results[0].plot(), caption="Result")
    ''')

# 2. تشغيل السيرفر وفتح اللينك (عن طريق ngrok)
from pyngrok import ngrok
import subprocess

# اقفلي أي أنفاق قديمة
ngrok.kill()
# حطي التوكن بتاعك هنا
ngrok.set_auth_token("37FLHCKq0LOhpl0aDdDgQEl57J5_4G36PAWAdie7spR8peheT")

# تشغيل streamlit في الخلفية
process = subprocess.Popen(['streamlit', 'run', 'app.py', '--server.port', '8501'])

# فتح اللينك
public_url = ngrok.connect(8501)
print(f"🔗 الرابط بتاعك أهو (Streamlit): {public_url}")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 53.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 37.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 80.1 MB/s eta 0:00:00
# 🔗 الرابط بتاعك أهو (Streamlit): NgrokTunnel: "https://nonfactual-darin-prestudiously.ngrok-free.dev" -> "http://localhost:8501"
